# %%
import pandas as pd

# %%
score = [['홍길동', 100, 90, 80],
        ['정약용', 80, 90, 100],
        ['규리', 10, 20, 30]]
score_df = pd.DataFrame(score, columns=['이름', '국어', '영어', '수학'])
score_df
# Out:
#     이름   국어  영어   수학
# 0  홍길동  100  90   80
# 1  정약용   80  90  100
# 2   규리   10  20   30

# %%
score_df.drop(['국어'], axis=1)
# Out:
# Empty DataFrame
# Columns: [이름, 국어, 영어, 수학]
# Index: []

# %%
score_df.drop([1], inplace=True)
